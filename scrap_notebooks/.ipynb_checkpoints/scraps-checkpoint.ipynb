# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import emcee 
import pyimfit 
from astropy.io import fits
import corner
from IPython.display import Latex
import sys
import warnings


plt.rcParams['image.cmap'] = 'Blues'
warnings.filterwarnings("ignore")

imageFile = "../fit/agn.fits"
imageAGN = fits.getdata(imageFile)

epsf = fits.getdata("../epsf2.fits")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 17
#      14 warnings.filterwarnings("ignore")
#      16 imageFile = "test.fits"
# ---> 17 imageAGN = fits.getdata(imageFile)
#      19 epsf = fits.getdata("epsf2.fits")
#
# File ~/miniconda3/envs/usc/lib/python3.11/site-packages/astropy/io/fits/convenience.py:220, in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     215 extver = kwargs.get("extver")
#     216 ext_given = not (
#     217     len(args) == 0 and ext is None and extname is None and extver is None
#     218 )
# --> 220 hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     221 try:
#     222     hdu = hdulist[extidx]
#
# File ~/miniconda3/envs/usc/lib/python3.11/site-packages/astropy/io/fits/convenience.py:1113, in _getext(filename, mode, ext, extname, extver, *args, **kwargs)
#    1110 elif extver and extname is None:
#    1111     raise TypeError("extver alone cannot specify an extension.")
# -> 1113 hdulist = fitsopen(filename, mode=mode, **kwargs)
#    1115 return hdulist, ext
#
# File ~/miniconda3/envs/usc/lib/python3.11/site-packages/astropy/io/fits/hdu/hdulist.py:213, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#     210 if not name:
#     211     raise ValueError(f"Empty filename: {name!r}")
# --> 213 return HDUList.fromfile(
#     214     name,
#     215     mode,
#     216     memmap,
#     217     save_backup,
#     218     cache,
#     219     lazy_load_hdus,
#     220     ignore_missing_simple,
#     221     use_fsspec=use_fsspec,
#     222     fsspec_kwargs=fsspec_kwargs,
#     223     **kwargs,
#     224 )
#
# File ~/miniconda3/envs/usc/lib/python3.11/site-packages/astropy/io/fits/hdu/hdulist.py:476, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     457 @classmethod
#     458 def fromfile(
#     459     cls,
#    (...)
#     467     **kwargs,
#     468 ):
#     469     """
#     470     Creates an `HDUList` instance from a file-like object.
#     471
#    (...)
#     474     documentation for details of the parameters accepted by this method).
#     475     """
# --> 476     return cls._readfrom(
#     477         fileobj=fileobj,
#     478         mode=mode,
#     479         memmap=memmap,
#     480         save_backup=save_backup,
#     481         cache=cache,
#     482         ignore_missing_simple=ignore_missing_simple,
#     483         lazy_load_hdus=lazy_load_hdus,
#     484         **kwargs,
#     485     )
#
# File ~/miniconda3/envs/usc/lib/python3.11/site-packages/astropy/io/fits/hdu/hdulist.py:1146, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#    1143 if fileobj is not None:
#    1144     if not isinstance(fileobj, _File):
#    1145         # instantiate a FITS file object (ffo)
# -> 1146         fileobj = _File(
#    1147             fileobj,
#    1148             mode=mode,
#    1149             memmap=memmap,
#    1150             cache=cache,
#    1151             use_fsspec=use_fsspec,
#    1152             fsspec_kwargs=fsspec_kwargs,
#    1153         )
#    1154     # The Astropy mode is determined by the _File initializer if the
#    1155     # supplied mode was None
#    1156     mode = fileobj.mode
#
# File ~/miniconda3/envs/usc/lib/python3.11/site-packages/astropy/io/fits/file.py:217, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs)
#     215     self._open_fileobj(fileobj, mode, overwrite)
#     216 elif isinstance(fileobj, (str, bytes)):
# --> 217     self._open_filename(fileobj, mode, overwrite)
#     218 else:
#     219     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/miniconda3/envs/usc/lib/python3.11/site-packages/astropy/io/fits/file.py:626, in _File._open_filename(self, filename, mode, overwrite)
#     623 ext = os.path.splitext(self.name)[1]
#     625 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 626     self._file = open(self.name, IO_FITS_MODES[mode])
#     627     self.close_on_error = True
#     629 # Make certain we're back at the beginning of the file
#     630 # BZ2File does not support seek when the file is open for writing, but
#     631 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.fits'

# %%
def galaxy_model(X0, Y0, X1, Y1, Xss0, Yss0, Xss1, Yss1, Xlim, Ylim,
                 PA_ss, ell_ss, n_ss, I_ss, r_ss, Itot,
                 PA_lim, ell_lim, I_lim, sigma_lim, Iss_lim, rss_lim):
    """create galaxy model for ML fit
        including: ps: 1 psf + 1 sersic
                   psps: 2 psf + 2 sersic"""

    sersic = {'PA': [PA_ss, PA_lim[0],PA_lim[1]], 'ell_bulge': [ell_ss, ell_lim[0],ell_lim[1]], 'n': [n_ss, 'fixed'],
    'I_e': [I_ss, Iss_lim[0],Iss_lim[1]], 'r_e': [r_ss, rss_lim[0],rss_lim[1]]}
    sersic_dict = {'name': "Sersic", 'label': "bulge", 'parameters': sersic}
    
    psf = {'I_tot' : Itot}
    psf_dict = {'name': "PointSource", 'label': "psf", 'parameters': psf}

    funcset_dict_psf0 = {'X0': [X0,Xlim[0],Xlim[1]], 'Y0': [Y0, Ylim[0],Ylim[1]], 
                    'function_list': [psf_dict]}
    funcset_dict_psf1 = {'X0': [X1,Xlim[0],Xlim[1]], 'Y0': [Y1, Ylim[0],Ylim[1]], 
                    'function_list': [psf_dict]}
    funcset_dict_sersic0 = {'X0': [Xss0,Xlim[0],Xlim[1]], 'Y0': [Yss0,Ylim[0],Ylim[1]], 
                   'function_list': [sersic_dict]}
    funcset_dict_sersic1 = {'X0': [Xss1,Xlim[0],Xlim[1]], 'Y0': [Yss1,Ylim[0],Ylim[1]], 
                   'function_list': [sersic_dict]}
    
    funcset_dict_psfser0 = {'X0': [X0,Xlim[0],Xlim[1]], 'Y0': [Y0, Ylim[0],Ylim[1]], 
                    'function_list': [psf_dict, sersic_dict]}
    funcset_dict_psfser1 = {'X0': [X1,Xlim[0],Xlim[1]], 'Y0': [Y1, Ylim[0],Ylim[1]], 
                    'function_list': [psf_dict, sersic_dict]}
    

    
    
    model_dict_ps_1c = {'function_sets': [funcset_dict_psfser0]}
    model_dict_psps_1c = {'function_sets': [funcset_dict_psfser0,funcset_dict_psfser1]}
    
    model_dict_ps_2c = {'function_sets': [funcset_dict_psf0,funcset_dict_sersic0]}
    model_dict_psps_2c = {'function_sets': [funcset_dict_psf0, funcset_dict_psf1,funcset_dict_sersic0,funcset_dict_sersic1]}
    
    model_ps1c = pyimfit.ModelDescription.dict_to_ModelDescription(model_dict_ps_1c)
    model_psps1c = pyimfit.ModelDescription.dict_to_ModelDescription(model_dict_psps_1c)
    model_ps2c = pyimfit.ModelDescription.dict_to_ModelDescription(model_dict_ps_2c)
    model_psps2c = pyimfit.ModelDescription.dict_to_ModelDescription(model_dict_psps_2c)
    return model_ps1c, model_psps1c, model_ps2c, model_psps2c


def doFit(models,epsf): 
    """do fit and return fitters, best fit params, and labels"""
    fitters = []
    for i in range(len(models)):
        imfit_fitter = pyimfit.Imfit(models[i],psf=epsf)
        psfOsamp = pyimfit.MakePsfOversampler(epsf, 4, (0,100,0,100))
        osampleList = [psfOsamp]
        imfit_fitter = pyimfit.Imfit(model_ps1c_n1,psf=epsf)
        imfit_fitter.loadData(imageAGN, psf_oversampling_list=osampleList, gain=9.942e-1, read_noise=0.22, original_sky=15.683)
        fitters.append(imfit_fitter)
    return fitters

def find_highest_indices(arr):
    flattened_arr = np.array(arr).flatten()
    max_indices = np.unravel_index(np.argsort(flattened_arr)[-2:], arr.shape)
    return max_indices

# %%
starpos = find_highest_indices(imageAGN)
center = (starpos[0]+starpos[1])/2
Imax = imageAGN.max()
#create galaxy models
itot=epsf.sum()
model_ps1c_n1, model_psps1c_n1, model_ps2c_n1, model_psps2c_n1 = galaxy_model(X0=starpos[0][0], Y0=starpos[0][1], X1=starpos[1][0], Y1=starpos[1][1], 
                                                 Xss0=starpos[0][0], Yss0=starpos[0][1], Xss1=starpos[1][0], Yss1=starpos[1][1],
                                                 Xlim=[0,100], Ylim=[0,100],
                                                 PA_ss=200, ell_ss=0.1, n_ss=1, I_ss=1, r_ss=20, Itot=itot,
                                                 PA_lim=[0,360], ell_lim=[0.0,1.0], I_lim=[0,Imax], sigma_lim=[0,15],
                                      Iss_lim=[0,Imax], rss_lim=[0,100])

# %%
psfOsamp = pyimfit.MakePsfOversampler(epsf, 4, (40,60,40,60))
osampleList = [psfOsamp]
imfit_fitter_gsgsn1c1 = pyimfit.Imfit(model_psps1c_n1,psf=epsf)
imfit_fitter_gsgsn1c1.loadData(imageAGN, psf_oversampling_list=osampleList, gain=9.942e-1, read_noise=0.22, original_sky=15.683)
imfit_fitter_gsgsn1c1.doFit()
plt.imshow(imfit_fitter_gsgsn1c1.getModelImage())
# Out:
# PsfOversampling: starting initialization...
# 141
# PsfOversampling: done.
# PsfOversampling: starting __dealloc__.
# PsfOversampling: done with __dealloc__.

# %%
plt.imshow(imfit_fitter_gsgsn1c1.getModelImage()-imageAGN)

# %%
for para, fit in zip(imfit_fitter_gsgsn1c1.numberedParameterNames, imfit_fitter_gsgsn1c1.getFitResult().params):
    print(f"{para}: {fit:.3f}")
# Out:
# X0_1: 53.414
# Y0_1: 53.523
# I_tot_1: 2177.669
# PA_2: 295.124
# ell_bulge_2: 0.410
# n_2: 1.000
# I_e_2: 1.364
# r_e_2: 27.765
# X0_2: 48.399
# Y0_2: 57.674
# I_tot_3: 1930.352
# PA_4: 248.554
# ell_bulge_4: 0.383
# n_4: 1.000
# I_e_4: 15.838
# r_e_4: 10.806
